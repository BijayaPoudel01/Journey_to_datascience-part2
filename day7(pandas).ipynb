# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\datascience class\Datascience (saroj sir)\DataScience\movies.csv')
df1
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 4                                 Joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         Kumonosu-jô           1957      110   Drama
# 296                        Falling Down           1993      113  Action
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
# 299                         Kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %%
df1.sort_values(['Released_Year'],inplace=True)
df1
# Out:
#                           Series_Title  Released_Year  Runtime      Genre  \
# 115       Das Cabinet des Dr. Caligari           1920       76    Fantasy
# 148                         The Circus           1928       72     Comedy
# 9           La passion de Jeanne d'Arc           1928      110  Biography
# 122  M - Eine Stadt sucht einen Mörder           1931      117      Crime
# 80   Scarface: The Shame of the Nation           1932       93     Action
# ..                                 ...            ...      ...        ...
# 4                                Joker           2019      122      Crime
# 251                  Avengers: Endgame           2019      181     Action
# 227                              Klaus           2019       96  Animation
# 141                               Soul           2020      100  Animation
# 280                           Hamilton           2020      160  Biography
#
#      IMDB_Rating             Director                  Star1  No_of_Votes  \
# ...

# %%
df1.sort_values(['Runtime'],ascending=False).head() #lengthy runtime
# Out:
#                Series_Title  Released_Year  Runtime      Genre  IMDB_Rating  \
# 170      Gangs of Wasseypur           2012      321     Action          8.2
# 59       Gone with the Wind           1939      238      Drama          8.1
# 154                 Ben-Hur           1959      212  Adventure          8.1
# 42   Swades: We, the People           2004      210      Drama          8.2
# 180    Shichinin no samurai           1954      207     Action          8.6
#
#                Director            Star1  No_of_Votes        Gross  Metascore
# 170      Anurag Kashyap   Manoj Bajpayee        82365    5257741.0       89.0
# 59       Victor Fleming     George Cukor       290074  198676459.0       97.0
# 154       William Wyler  Charlton Heston       219466   74700000.0       90.0
# 42   Ashutosh Gowariker   Shah Rukh Khan        83005    1223240.0        NaN
# 180      Akira Kurosawa   Toshirô Mifune       315744     269061.0       98.0

# %% [markdown]
# ### Sorting between two columns

# %%
df1.sort_values(['Genre','IMDB_Rating'],ascending=[True,False])
# Out:
#                      Series_Title  Released_Year  Runtime      Genre  \
# 129               The Dark Knight           2008      152     Action
# 77                     The Matrix           1999      136     Action
# 180          Shichinin no samurai           1954      207     Action
# 104    Terminator 2: Judgment Day           1991      137     Action
# 190         The Dark Knight Rises           2012      164     Action
# ..                            ...            ...      ...        ...
# 29                  The Third Man           1949      104  Film-Noir
# 75                  The Innocents           1961      100     Horror
# 156                           Saw           2004      103     Horror
# 94                      Dark City           1998      100    Mystery
# 195  Once Upon a Time in the West           1968      165    Western
#
#      IMDB_Rating           Director                  Star1  No_of_Votes  \
# ...

# %% [markdown]
# ###  chanding the columns names

# %%
df1.rename(columns={'Series_Title':'Movies_Name','Runtime':'Movies_Length'})
# Out:
#                            Movies_Name  Released_Year  Movies_Length  \
# 115       Das Cabinet des Dr. Caligari           1920             76
# 148                         The Circus           1928             72
# 9           La passion de Jeanne d'Arc           1928            110
# 122  M - Eine Stadt sucht einen Mörder           1931            117
# 80   Scarface: The Shame of the Nation           1932             93
# ..                                 ...            ...            ...
# 4                                Joker           2019            122
# 251                  Avengers: Endgame           2019            181
# 227                              Klaus           2019             96
# 141                               Soul           2020            100
# 280                           Hamilton           2020            160
#
#          Genre  IMDB_Rating             Director                  Star1  \
# ...

# %% [markdown]
# ### Filtering Data

# %%
df1['Genre']=='Comedy' #boolean series
# Out:
# 115    False
# 148     True
# 9      False
# 122    False
# 80     False
#        ...
# 4      False
# 251    False
# 227    False
# 141    False
# 280    False
# Name: Genre, Length: 300, dtype: bool

# %%
df1[df1['Genre']=='Comedy']
# Out:
#                                         Series_Title  Released_Year  Runtime  \
# 148                                       The Circus           1928       72
# 132                                     The Thin Man           1934       91
# 259                             A Night at the Opera           1935       96
# 131                                 Bringing Up Baby           1938      102
# 260                       The Shop Around the Corner           1940       99
# 277                             Arsenic and Old Lace           1942      118
# 149                           Miracle on 34th Street           1947       96
# 66                                           Sabrina           1954      113
# 250                                 Some Like It Hot           1959      121
# 173                                     Mary Poppins           1964      139
# 127                               A Hard Day's Night           1964       87
# ...

# %% [markdown]
# ### Fetch all the movies from genre action and imdb rating>8.5.

# %%
df1[(df1['Genre']=='Action') & (df1['IMDB_Rating']>8.5)]
# Out:
#              Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 180  Shichinin no samurai           1954      207  Action          8.6
# 77             The Matrix           1999      136  Action          8.7
# 129       The Dark Knight           2008      152  Action          9.0
#
#               Director            Star1  No_of_Votes        Gross  Metascore
# 180     Akira Kurosawa   Toshirô Mifune       315744     269061.0       98.0
# 77      Lana Wachowski  Lilly Wachowski      1676426  171479930.0       73.0
# 129  Christopher Nolan   Christian Bale      2303232  534858444.0       84.0

# %% [markdown]
# ### Fetch the movies which is released in 2018 or genre Action.

# %%
df1[(df1['Genre']=='Action') | (df1['Released_Year']==2018)]
# Out:
#                                           Series_Title  Released_Year  \
# 80                   Scarface: The Shame of the Nation           1932
# 205                                          Key Largo           1948
# 184                                          Red River           1948
# 185                                         White Heat           1949
# 180                               Shichinin no samurai           1954
# 14                                     The Longest Day           1962
# 261                                    The Dirty Dozen           1967
# 246                                     The Wild Bunch           1969
# 143                                        Dirty Harry           1971
# 231                                       Blade Runner           1982
# 284                                     The Terminator           1984
# 36                                       Lethal Weapon           1987
# ...

# %% [markdown]
# ### Find the unique values from the Genre

# %%
df1['Genre'].unique()
# Out:
# array(['Fantasy', 'Comedy', 'Biography', 'Crime', 'Action', 'Drama',
#        'Adventure', 'Film-Noir', 'Horror', 'Western', 'Animation',
#        'Mystery'], dtype=object)

# %% [markdown]
# ### Value_counts

# %%
df1['Genre'].value_counts() #counts total number of rows.
# Out:
# Genre
# Drama        86
# Comedy       50
# Action       50
# Crime        37
# Animation    29
# Biography    29
# Adventure    13
# Horror        2
# Fantasy       1
# Film-Noir     1
# Western       1
# Mystery       1
# Name: count, dtype: int64

# %%
df1[df1['Genre']=='Action'].shape
# Out:
# (50, 10)

# %% [markdown]
# ## Find the top 5 genre of movies with highest frequency.

# %%
df1['Genre'].value_counts().head()
# Out:
# Genre
# Drama        86
# Comedy       50
# Action       50
# Crime        37
# Animation    29
# Name: count, dtype: int64

# %%
df1['Genre'].value_counts().head()
# Out:
# Genre
# Drama        86
# Comedy       50
# Action       50
# Crime        37
# Animation    29
# Name: count, dtype: int64

# %% [markdown]
# ### Fetch only 3 :

# %%
df1[['Series_Title','Runtime','Genre']]
# Out:
#                           Series_Title  Runtime      Genre
# 115       Das Cabinet des Dr. Caligari       76    Fantasy
# 148                         The Circus       72     Comedy
# 9           La passion de Jeanne d'Arc      110  Biography
# 122  M - Eine Stadt sucht einen Mörder      117      Crime
# 80   Scarface: The Shame of the Nation       93     Action
# ..                                 ...      ...        ...
# 4                                Joker      122      Crime
# 251                  Avengers: Endgame      181     Action
# 227                              Klaus       96  Animation
# 141                               Soul      100  Animation
# 280                           Hamilton      160  Biography
#
# [300 rows x 3 columns]

# %% [markdown]
# ### Find the average IMDB_Rating of the movies.

# %%
df1['IMDB_Rating']
# Out:
# 115    8.1
# 148    8.1
# 9      8.1
# 122    8.3
# 80     7.8
#       ...
# 4      8.5
# 251    8.4
# 227    8.2
# 141    8.1
# 280    8.6
# Name: IMDB_Rating, Length: 300, dtype: float64

# %%
df1['IMDB_Rating'].mean()
# Out:
# np.float64(7.963333333333333)

# %% [markdown]
# ### find the mean Imbd rating of Genre Action.

# %%
df1[df1['Genre']=='Action']['IMDB_Rating'].mean()
# Out:
# np.float64(7.9639999999999995)

# %% [markdown]
# ### Find the maximum IMBD rating of action genre.

# %%
df1[df1['Genre']=='Action']['IMDB_Rating'].max()
# Out:
# np.float64(9.0)

# %%
df1[df1['Genre']=='Action']['IMDB_Rating'].nlargest() # top 5 largest imdb ratings.
# Out:
# 129    9.0
# 77     8.7
# 180    8.6
# 104    8.5
# 190    8.4
# Name: IMDB_Rating, dtype: float64

# %%
df1[df1['Genre']=='Action']['IMDB_Rating'].nsmallest()
# Out:
# 36     7.6
# 296    7.6
# 15     7.6
# 61     7.6
# 281    7.6
# Name: IMDB_Rating, dtype: float64

# %%
df1[df1['Genre'] == 'Action'].sort_values('IMDB_Rating', ascending=False)
# Out:
#                                           Series_Title  Released_Year  \
# 129                                    The Dark Knight           2008
# 77                                          The Matrix           1999
# 180                               Shichinin no samurai           1954
# 104                         Terminator 2: Judgment Day           1991
# 190                              The Dark Knight Rises           2012
# 251                                  Avengers: Endgame           2019
# 168                                         Hera Pheri           2000
# 5                                      Andaz Apna Apna           1994
# 71                            Uri: The Surgical Strike           2018
# 170                                 Gangs of Wasseypur           2012
# 225                                            Warrior           2011
# 253                                  Kill Bill: Vol. 1           2003
# ...

# %% [markdown]
# ### Find the missing  values in each columns.

# %%
df1.isnull()
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 115         False          False    False  False        False     False
# 148         False          False    False  False        False     False
# 9           False          False    False  False        False     False
# 122         False          False    False  False        False     False
# 80          False          False    False  False        False     False
# ..            ...            ...      ...    ...          ...       ...
# 4           False          False    False  False        False     False
# 251         False          False    False  False        False     False
# 227         False          False    False  False        False     False
# 141         False          False    False  False        False     False
# 280         False          False    False  False        False     False
#
#      Star1  No_of_Votes  Gross  Metascore
# 115  False        False  False       True
# ...

# %%
df1.isnull().sum()
# Out:
# Series_Title      0
# Released_Year     0
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Director          0
# Star1             0
# No_of_Votes       0
# Gross             0
# Metascore        36
# dtype: int64
